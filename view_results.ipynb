# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/walml/repos/active_learning/results/latest_model.csv')
# df = pd.read_csv('/home/walml/repos/active_learning/results/latest_model_actually_logreg.csv')

# %%
plt.plot(df['x1 pytorch_L'], df['uncertainty_1'], color='b', label='Uncertainty & LogReg')
plt.plot(df['x1 pytorch_L'], df['random_1'], linestyle='--', color='b', label='Random & LogReg')
plt.plot(df['x2 pytorch_N'], df['uncertainty_2'], color='r', label='Uncertainty & MLP')
plt.plot(df['x2 pytorch_N'], df['random_2'], linestyle='--', color='r', label='Random & MLP')
# plt.plot(df['x1 pytorch_N'], df['random_1'], linestyle='--', color='b', label='Random & LogReg')
plt.xlabel('Galaxies')
plt.ylabel('Score')
plt.legend()
plt.ylim([2, 3])
# Out:
# (2.0, 3.0)
